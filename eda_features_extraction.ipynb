# %%
import pandas as pd
import numpy as np
import plotly.express as px
import re

# %%
houses = pd.read_csv("../Data/riyadh_houses_original.csv")

pd.options.display.max_colwidth = 1000

# %%
houses.sample(50)
# Out:
#                                                       listTitle          time  \
# 7701  فيلا للبيع في شارع هبة الله بن عساكر ، حي الخليج ، الرياض    قبل 6 ايام
# 893               فيلا للبيع في شارع المجاز ، حي الحزم ، الرياض     قبل اسبوع
# 1229                                       فيلا للبيع في الرياض     قبل يومين
# 6462                                       فيلا للبيع في الرياض       قبل يوم
# 8298                فيلا للبيع في طريق الملك عبدالعزيز ، الرياض     قبل شهرين
# 3773      فيلا للبيع في شارع ابن زيادة ، حي صلاح الدين ، الرياض    قبل 3 ايام
# 614                 فيلا للبيع في طريق الملك عبدالعزيز ، الرياض  قبل 36 دقيقة
# 5299                                       فيلا للبيع في الرياض   قبل اسبوعين
# 2412                     فيلا للبيع في المملكة العربية السعودية       قبل يوم
# 9003                           فيلا للبيع في حي الملقا ، الرياض     قبل يومين
# 6340                                       فيلا للبيع في الرياض    قبل 3 ايام
# 9582                    فيلا للبيع في طريق خريص القديم ، الرياض    قبل 3 شهور
# 2809        فيلا للبيع في شارع وادي ابو عرب ، حي ديراب ، الرياض   قبل 15 ساعة
# 6339           فيلا للبيع في شارع الطائف ، حي ظهرة لبن ، الرياض       قبل يوم
# 1508                         فيلا للبيع في حي القيروان ، الرياض       قبل يوم
# 3643     فيلا للبيع في شارع عبدالله المويس ، حي الرمال ، الرياض   قبل اسبوعين
# 1460                           فيلا للبيع في حي الرمال ، الرياض    قبل 3 ساعة
# 4029                            فيلا للبيع في حي الحزم ، الرياض    قبل 4 ايام
# 2981                            فيلا للبيع في حي قرطبة ، الرياض       قبل شهر
# 1740                   فيلا للبيع في طريق السيل الكبير ، الرياض    قبل 6 ايام
# 7282                                       فيلا للبيع في الرياض    قبل 6 ايام
# 6243                                       فيلا للبيع في الرياض       قبل شهر
# 2300                                       فيلا للبيع في الرياض     قبل اسبوع
# 1954              فيلا للبيع في شارع الطوارف ، حي طويق ، الرياض   قبل اسبوعين
# 7341            فيلا للبيع في شارع أبي القاسم الأنصاري ، الرياض       قبل شهر
# 3992                                       فيلا للبيع في الرياض     قبل شهرين
# 6801                            فيلا للبيع في شارع 246 ، الرياض    قبل 3 ايام
# 9328                   فيلا للبيع في طريق السيل الكبير ، الرياض  قبل 3 اسابيع
# 4137                                       فيلا للبيع في الرياض    قبل 8 ساعة
# 1758                           فيلا للبيع في حي النظيم ، الرياض     قبل اسبوع
# 8010                             فيلا للبيع في حي طويق ، الرياض    قبل 5 ايام
# 8565                                       فيلا للبيع في الرياض    قبل 8 ساعة
# 9341                 فيلا للبيع في شارع احمد بن الخطاب ، الرياض    قبل 5 ايام
# 7376                فيلا للبيع في طريق الملك عبدالعزيز ، الرياض       قبل شهر
# 6844                         فيلا للبيع في حي الياسمين ، الرياض    قبل 9 ساعة
# 312                                        فيلا للبيع في الرياض    قبل 7 ساعة
# 5658                     حي العارض - الرياض   362  1750000         4
# 3994                       حي طويق - الرياض   375  1100000         4
# 297                      حي الرمال - الرياض   336  1100000         3
# 7615                       حي طويق - الرياض   515  1000000         5
# 3728                    حي السعادة - الرياض   351  1300000         6
# 8533                     حي الملقا - الرياض   500  3300000         5
# 4125                     حي الرمال - الرياض   276  1100000         4
# 5272                   حي القادسية - الرياض   406  1600000         5
# 4333                       حي طويق - الرياض   375  1150000         5
# 5207                       حي طويق - الرياض   450  1050000         5
# 9673                     حي الرمال - الرياض   656  1900000         5
# 1865                       حي طويق - الرياض   360  1180000         5
#
#       bathrooms  \
# 7701          3
# 893           5
# 1229          5
# 6462          3
# 8298          4
# 3773          5
# 614           5
# 5299          5
# 2412          4
# 9003          3
# 6340          5
# 9582          2
# 2809          5
# 6339          5
# 1508          3
# 3643          5
# 1460          4
# 4029          5
# 2981          5
# 1740          5
# 7282          1
# 6243          4
# 2300          3
# 1954          5
# 7341          5
# 3992          5
# 6801          5
# 9328          3
# 4137          5
# 1758          5
# 8010          5
# 8565          3
# 9341          5
# 7376          3
# 6844          5
# 312           5
# 7983          5
# 1314          5
# 5658          5
# 3994          5
# 297           4
# 7615          5
# 3728          4
# 8533          4
# 4125          4
# 5272          3
# 4333          5
# 5207          5
# 9673          5
# 1865          5
#
#                                                                                                                                                                                                                                                                           details
# 7701      شارع جنوبي 10م وشمالي 8م \nدور دور مفصول \nالدور الاول مجلس مقلط صاله عدد ثلاث غراف نوم حوش مدخل سياره \nالدور الثاني نفس الدور الاول \nمواجر ‏بالكامل 40الف \n\nالعماره مرهونه عند بنك العقار \nباقي من القرض ‏تقريبا 100الف ‏:\n‏القصد الشهري 1000ريال \n\n(العقار...
# 893                                                                                             درج صالة وشقة مودرن تحت التشطيب وممكن المشاركة بالتشطيبات والاختيارات يوجد عدد 8 فلل متفرقة بالموقع ولدي تخليص وحسبة لدى البنوك\nالصورة للشكل النهائي والفلة تحت التشطيب والإنشاء
# 1229  الحي :النرجس 4 \nالمساحة:437 \nالواجهة: شمالية \nالشارع:15\n\nمدخل سيارة + غرفة سائق + ملحق + مصعد\n\nالدور الارضي:\nمجلس ودورة مياه + صالة طعام  + صالة جلوس كبيرة ودورة مياه +مطبخ \n\nالدور الاول:\nغرفتين ماستر + غرفتين بدورة مياه\n\nالدور الثاني:\nغرفة خادمة وغس...
# 6462                                                                                                                                                                                                                                                   فيلا للبيع دور + دور + شقة
# 8298                                                                       ڤيلا بحي العارض ..\nمقدمة حوش مع ملحق خارجي \nمجلس ، مقلط ، صالة واسعة \nأربع غرف نوم بدورات مياه ، غرفة سائق وغرفة خادمة وغسيل \n\n-درج داخلي \n-بالإضافة إلى شقتين \n\n\nاللوكيشن غير دقيق ✨\n\nV172
# 3773                                                                                                                                                                                                                        عمر الفيلا 11سنه يوجد بها حوش ومدخل السيارات وبها قبو
# 614                                                                                                                                                                          ڤيلا بالقمرا ٧ \nبناء شخصي مميز جداً . \n\nيشتمل على شقة ، مصعد مؤسس \n\nاللوكيشن غير دقيق ✨\n\nV222
# 5299                                                                                                                                                                                                                       دبلكس مساحته ٢٠٠ ف التقاطع الاول تصميم فاخر وشغل مضمون
# 2412                                                                                                                                                                                                                                                             درج داخلي وشقتين
# 9003          للبيع فيلا درج صالة \nفي حطين النموذجي مساحة \n٤٢٠متر وجهة شرقية شارع ١٥م \nالدور الارضي إستقبال بالكامل ويتكون مدخل سيارة غرفة سايق مجلس ومقلط وصالة ومجلس نساء \nملحق خارجي ومسبح ومصعد\nالدور الأول علوي ٥ غرف نوم ماستر مع صالة \nالسطح غرف بحمام وغرفة غسيل...
# 6340             دبلكس مفصول من الخارج بحي المهديه 200م السعر850 الف وجهه شماليه وصف العقار تتكون من مدخل سياره /مشب /مقلط /مجلس رجال/مجلس نساء/صاله /مطبخ /3دورات مياه /\nالدور العلوى غرفتين نوم مستر /غرفتين حمام خارجي /صاله /\nوالسطح غرفتين نوم وحمام وملحق\nعليه جميع ا...
# 9582                                                                                                                                                     العقار شغل شخصي وعلي الشرط دور ارضي مصممه علي دور وثلاث شقق         \n\nالاتصال علي هذا الرقم انا مجرد معلن \n٠٥٠٣٤٦١٦٨٨
# 2809            فلة مكونه من دراج وصاله وشقتين مساحه  325 الشفا خط ديراب     يوجد جميع الضمانات ويوجد لدينا حلول تمويليه ميسره باقل هامش ربح من جميع البنوك حلول للدفعة الأولى والمديونية ابو نواف شركة ابراج نمار للخدمات العقاريه \nللتواصل  \nابو نواف\nرقم الجوال\n 055633...
# 6339             فيلا فاخره بحي لبن الشرقي موقع مميزبالقرب من الدائري وجميع الخدمات عمرها 7 سنين بناء شخصي \nالدور الاول مشب نساء وملحق رجال مجلس نساء ورجال صاله وصالة طعام ومطبخ ودورتين مياه\nالدور الثاني 3 اجنحة نوم وغرفتين نوم وصاله \nالدور الثالث غرفتين وصاله ودورتي...
# 1508                                                                                                                                                                                                                                             للبيع دبلكسات القيروان درج داخلي
# 3643                              فيلا درج صاله وشقتين مسروقه م 330 واجهة غربيه حى الواحة الرمال واجهة غربيه شارع 15 تشطيبات فاخرة الأرضى مدخل سيارة ومشب ومجلس ومقلط وصاله ومطبخ وغرفة كبار سن و2 حمام العلوى 3 غرف نوم وصالة السطح غرفة خادمه مع حمام \nالشقق 3 غرف وصاله ومطبخ
# 1460   🏡 فيلا درج داخلي+ شقتين 🏡\n\n🌍حي الرمال مخطط واحة الرمال🌏\n\nتتكون من↙️\n\nحوش +ملحق مشب\n + مجلس رجال + مقلط\n + مطبخ + صالة\n + مجلس حريم + غرفة نوم ارضيه\n\nالدور الثاني↙️\n\nغرفتين نوم ماستر روم + غرفة نوم\n\nالدور الثالث↙️\nغرفة خادمه + سطح.\nتشطيبات ممتازه ...
# 4029                                                                                                                                                                                                                               فله دور مسروق وشقه دورين \nمكتب امدادات العطاء
# 2981                                                                                                                                                                                                                      بناء شخصي .\nضمانات شاملة .\nاشراف هندسي .\nموقع مميز .
# 9673          للبيع فيلا في حي الرمال التعمير المساحه ٦٥٦م درج صاله وشقتين مسبح وحديقه وشلال واصنصير مصعد إشراف هندسي\n\n\n وضمانات شامله \nضمان على الخزانات العلوي 10سنه ضمان السباكه ضمان 15سنه الانابيب الخضراء\nالكهرباء ضمنان 15سنه التراء الفنار \nصبيات بمب ضمان 10سنه...
# 1865        السلام عليكم مساكم الله بالخير\nتقدم شركة دار المستفيد العقارية \nلعملائها الكرام عرضها المميز \nفيلا عبارة عن درج داخلى مع شقتين\nبحى الغروب\nعبارة عن مشب ومجلس رجال ومقلط\nوصالة ومجلس نساء  ومطبخ ودورتين مياة\nالدور التانى اربع غرف  وتلات دورات مياة \nالدو...

# %% [markdown]
# ---
# ## Extract from 'time' feature:

# %%
def extract_pattern(series, pattern, other_value=np.nan):
    '''
    this function creates new series that have extracted pattern from the original series elements,
    and other_value in every un-match element.
    
    params:
    series: the series that will match its element with the pattern.
    pattern: pattern that will try to find in every element and extract.
    other_value: the value that will put in every un-match element.
    
    return:
    new series.
    '''
    new_series = []
    for string in series:
        pattern = re.compile(pattern)
        matches = re.findall(pattern, string)
        
        if matches:
            new_series.append(matches[0])
        else:
            new_series.append(other_value)
    
    return pd.Series(new_series)



def map_pattern(series, pattern, match_value, other_value):
    '''
    this function creates new series that have the match_value in every matching pattern
    from the original series elements, and other_value in every un-match element.
    
    params:
    series: the series that will match its element with the pattern.
    pattern: pattern that will try to find in every element.
    match_value: the value that will put if the element is matching hte pattern.
    other_value: the value that will put in every un-match element.
    
    return:
    new series.
    '''
    new_series = []
    for string in series:
        pattern = re.compile(pattern)
        matches = re.finditer(pattern, string)
        matches = tuple(matches)
    
        is_there_match = bool(matches)
        if is_there_match:
            new_series.append(match_value)
        else:
            new_series.append(other_value)
    
    return pd.Series(new_series)



def map_patterns_collection(series, pattern_value_pairs, other_value):
    '''
    this function creates new series that have all match_values in every matching patterns
    in the patterns pairs, and apply it to the original series elements, and the rest of elements 
    that haven't any match it will assign other_value.
    
    params:
    series: the series that will match its element with the patterns.
    pattern_value_pairs: list of tuples have (pattern, value) pair, will try to find every pattern
                         in the pair in the element, if found will assign its paired value.
    other_value: the value that will put in every element that haven't any match.
    
    return:
    new series.
    '''
    matches = []
    for pattern_value in pattern_value_pairs:
        match = map_pattern(series, pattern_value[0], pattern_value[1], other_value)
        matches.append(match)
        
    return sum(matches)



def mins_unit_factor(series, other_value=0):
    '''
    this function creates new series that have minutes unit factor for every pattern in arabic,
    for example: element with the word "ساعة" will put its factor to 60, means the hour have 60 mins
     
    params:
    series: the series that will match its element with the mins unis factor patterns.
    other_value: the value that will put in every element that haven't any time match.
    
    return:
    new series.
    '''
    min_pattern = r"دق"
    hour_pattern = r"ساع"
    day_pattern = r"(يوم|يام)"
    week_pattern = r"(سبوع|سابيع)"
    month_pattern = r"(شهر|شهرين|شهور)"
    year_pattern = r"(سنة|سنين|سنتين|سنه)"
    patterns_collection = [
        (min_pattern, 1),                 # 1 min
        (hour_pattern, 60),               # 60 mins
        (day_pattern, 24*60),             # 1440 mins
        (week_pattern, 7*24*60),          # 10,080 mins
        (month_pattern, (365*24*60)/12 ), # 43,800 mins
        (year_pattern, 365*24*60)         # 525,600 mins
    ]
    
    return map_patterns_collection(series, patterns_collection, other_value)

# %%
def get_time_in_mins(time_series):
    '''
    this function extract time in minutes from arabic string.
    
    params:
    time_series: the series of arabic string that will extract time as mins from its element.
    
    return:
    dataframe have a column named time_in_mins. 
    '''
    time_df = pd.DataFrame()
    
    repeatation_pattern = r"[0-9]+"
    
    time_df['mins_factor'] = mins_unit_factor(time_series)
    time_df['repeatation_factor'] = extract_pattern(time_series, repeatation_pattern, other_value=1)
    
    binary_pattern = r"ين"
    time_df['binary_rep_factor'] = map_patterns_collection(time_series, [(binary_pattern, 2)], other_value=0)
    
    binary_mask = time_df['binary_rep_factor'] == 2
    time_df.loc[binary_mask, 'repeatation_factor'] = 2
    
    time_df['repeatation_factor'] = time_df['repeatation_factor'].astype('int')
    time_df['time_in_mins'] = time_df['repeatation_factor'] * time_df['mins_factor']
    
    time_df.drop(columns=['mins_factor', 'repeatation_factor', 'binary_rep_factor'], inplace=True)
    
    return time_df

# %%
#create new dataframe named time and copy the time column to it as time_text.
time = pd.DataFrame()
time['time_text'] = houses['time'].copy()

#get time in mins by calling the function, and then convert the time_in_mins series elements
#from int type to timedelta type.
time_in_mins = get_time_in_mins(time['time_text'])['time_in_mins']
time_duration = pd.to_timedelta(time_in_mins, unit='m')

#add the new time series that has the time as timedelta to the time dataframe and name its column as time_duration.
time['time_duration'] = time_duration

# %%
#show 10 random different rows from the dataframe.
time.sample(10)
# Out:
#          time_text    time_duration
# 7641    قبل 3 ايام  3 days 00:00:00
# 3301       قبل شهر 30 days 10:00:00
# 8663    قبل 3 شهور 91 days 06:00:00
# 7967   قبل اسبوعين 14 days 00:00:00
# 4084    قبل 6 ايام  6 days 00:00:00
# 9560    قبل 9 ساعة  0 days 09:00:00
# 2774      قبل ساعة  0 days 01:00:00
# 7536  قبل 3 اسابيع 21 days 00:00:00
# 607    قبل 11 ساعة  0 days 11:00:00
# 9012  قبل 3 اسابيع 21 days 00:00:00

# %% [markdown]
# ---
# ## Extract from 'location' feature:

# %%
#loop through location feature and find the pattern that extracting the neighborhood name only
#then assign it to neighborhoods list.
neighborhoods = []
neighborhood_pattern = r" [ء-ي]* -"

for string in houses['location']:
    pattern_compile = re.compile(neighborhood_pattern)
    matches = re.findall(pattern_compile, string)
    for match in matches:
        match = match.replace("-", "")
        match = match.strip()
        neighborhoods.append(match)


        
#creates new dataframe named location_df and assign the neighborhoods to it.
location_df = pd.DataFrame()
location_df['neighborhood'] = pd.Series(neighborhoods, dtype='object')

# %%
location_df.sample(10)
# Out:
#      neighborhood
# 2906         طويق
# 8443         طويق
# 9710       الضباط
# 2922         عكاظ
# 3990         عرقة
# 1473       العقيق
# 7841         طويق
# 6791       الرمال
# 3843       العارض
# 6383       الملقا

# %% [markdown]
# ---
# ## Extract from 'details' feature:

# %%
#living_rooms, garage, yard, street_nums, floors, apartments, details_value

#مستوى الحداثة
a = []
#الغرف الموجودة
b = []
#مواد البناء
c = []
#الحوش والسيارة
d = []
#عدد الشوارع ومساحتها
e = []
#عدد الادوار
f = []

houses.iloc[3:10]
# Out:
#                                                    listTitle         time  \
# 3                                       فيلا للبيع في الرياض   قبل 3 شهور
# 4                    فيلا للبيع في شارع وادي الساحل ، الرياض  قبل 13 ساعة
# 5                                       فيلا للبيع في الرياض   قبل 4 ساعة
# 6                  فيلا للبيع في شارع الغاط, التعاون, الرياض    قبل يومين
# 7                                       فيلا للبيع في الرياض   قبل 3 ايام
# 8  فيلا للبيع في شارع زينب بنت خزيمة ، حي الملك فهد ، الرياض  قبل 11 ساعة
# 9                           فيلا للبيع في حي الملقا ، الرياض   قبل 4 ساعة
#
#                    location  size    price  bedrooms  bathrooms  \
# 3          حي طويق - الرياض   336  1200000         4          5
# 4        حي الرمال - الرياض   373  1230000         4          4
# 5        حي النرجس - الرياض   300  1500000         5          4
# 6       حي التعاون - الرياض   625  3000000         5          5
# 7          حي طويق - الرياض   270  1050000         5          5
# 8     حي الملك فهد - الرياض  1500  3000000         3          2
# 9        حي الملقا - الرياض   340  2300000         4          5
#
#                                                                                                                                                                                                                                                             details
# 3                                                                                                               للبيع بحي طويق مخطط الغروب فيلا درج صاله وشقتين شارعين شرقي شمالي موقع ممتاز تعمير شخصي قريبه جدا من جامع السعيدان للاستفسار الاتصال على 0508209474
# 4  فيلا درج داخلي وشقتين بحى الرمال مخطط واحة الرمال) \n"بسم الله الرحمن الرحيم"\nشركة سكن المعالي العقارية تتشرف بخدمتكم وتسعى جاهدة لارضاء عملائها والعمل على راحتهم وتوفير الوقت والجهد وتقديم كل ماهو جديد في عالم العقارات .\nنوع العقار : درج داخلي وشقتين...
# 5    اربع فيلل في حى النرجس شمال الملك سلمان شرق ابوبكر الكيلو السادس حى مميز\nتتكون الفيلا من تحت استقبال كامل مجلس ومقلط وصاله وغرفة سائق وملحق خارجى مؤسس مصعد تكييف مركزى الدور الاول خمس اجنحه كل غرفة بحمام اكرمكم الله السطح غرفتين وصاله رياضة كبيره شغل...
# 6                                                                                                                                                                                                                 للبيع فيلا٦٢٥م درج داخلي في حي التعاون ٠٥٥٦٠٩٤٦٢٢
# 7                                                                                                                                                                                                                                                               NaN
# 8                                                               للبيع قصر قديم بقيمه ارض حي الملك فهد\n\nثلاث شوارع\n٢٠ جنوبى و١٠ شرقي و٨ غربي\n\nالمساحه ١٥٠٠م\nالاطوال ٣٠ عالجنوبي ×٥٠ عالغربي والشرقي\n\nالقصر عباره عن ٣ وحدات سكنيه الان\n\nمطلوب ٣ مليون صافي
# 9                                                                                فيلا بريارص الخزامي درج صاله مودرن ومصعد تكيف مخفي\n\nالدور الارضي\nمجلس ومقلط وصاله ومجلس نساء\n\nالدور الاول\n٤غرف نوم وصاله\nالدور الثاني\nغرفتين بلسطح\nالضمانات سباكه وكهرباء

# %%
def count_matches(series, pattern):
    details = houses['details'].copy()
    details.fillna("", inplace=True)
    
    matches_counts = []
    for string in series:
        pattern_compile = re.compile(pattern)
        matches = re.finditer(pattern_compile, string)
        matches = tuple(matches)
        matches_counts.append(len(matches))
        
    return pd.Series(matches_counts)

    
details = pd.DataFrame()
details['details'] = houses['details'].copy()
details['details'].fillna("", inplace=True)

living_rooms_pattern = r"(صالة|مجلس|مجالس|صالات|صاله|ديوانية|ديوانيه|مشب)"
details['living_rooms'] = count_matches(details['details'], living_rooms_pattern)

mask = details['living_rooms'] == 0
details.sample(50)
# Out:
#                                                                                                                                                                                                                                                                                      details  \
# 1538                                                                                                                                                                                                                                                  درج داخلي وشقه شارع ١٥ جنوبي شغل ممتاز
# 8901                 دبوس مثبّت\nبالقرب من الملقا، الرياض\nhttps://maps.app.goo.gl/qqLqa5LuxjuHbHmY7\n\n\nللبيع ٢ فيلا بحي الملقا غرب طريق الخير\nمساحة فيلاا ٤٥٠ متر\nجنوبية شارع ٢٠\nالتفاصيل\nالدور الأرضي\nمدخل سياره غرفه سائق ملحق خارجي مجلس استقبال ومقلط ومجلس نساء وغرفه كبار س...
# 6098                         فلل لبن \nفلتين دبلكس المساحة ٨٧٥ م \nمكونة كل فله من ٣ ادوار كل دور مكون من ٧ غرف ومطبخ و٣ دورات مياه مجالس كبيرة جميع الفلل ديكورات جبسية ورخام وباركية وغاز مركزي ومصاعد لكل فلة وجميع المغاسل رخام والبناء خاص وتشطيبات دلوكس ( سكن خاص ) مشب خارجي أمام...
# 9233                                                                                                                             فله جديده \nالمساحه ٣٧٢\nدور ودرج داخلي وشقتين \nشامله الضمنات على جميع ادوات السباكه والكهرباء\nبناء شخصي\nويوجد اكثر من فله بمساحة ٤٠٠ \nحي الرمال الواحه
# 9425                        اسعد الله اوقاتكم بكل خير تعلن شركة مبارك للعقارات عن وجود \nفيلا فاخره للبيع درج صاله وشقتين  بحي الحزم جنوب الرياض \nمساحة ٣١٢ متر واجهه شماليه وعرض الشارع ١٥ متر \nوالسعر مليون ريال حد تتميز بموقع ممتاز وقريب من المسجد والمرافق شغل شخصي تشطيب ممتاز ج...
# 9245                                                                              للبيع فيلا بحي رياض الخزامي\nمساحة  ٦٠٢م\nشارع ١٥ شمالي\nشغل مودرن\nمسبح ومصعد تكييف مخفي\n٥ اجنحه نوم وصالة واوفيس\nالصالة غرفة خادمة وغرفة غسيل وصالة العاب\nتحت التشطيب\nالبيع ٣ مليون و٧٠٠ غير الضريبه
# 8803                                                                                                                                                                           للبيع فيلا ممتازة شغل شخصى\nفيلا دوبلكس   مساحة ٢٩٠ م وعليها مليون و ٨٠ الف\nواجهه جنوبيه شارع ٢٠\nتشطيب لوكس
# 4923                للبيع فيلا درج صاله مع شقتين حي حطين النموذجي\nشرقيه شارع ١٥م\n\nالمساحه ٤٥٥م\nالمواصفات\nالدور الارضي استقبال بالكامل من مدخل سياره وملحق خارجي ومجلس رجال ومجلس نساء ومقلط وغرفه سائق ومطبخ ومستودع وغرفه خادمه وغسيل\n\nالدور العلوي\n٤ اجنحه وصاله\n\nالشقق\nالدو...
# 8894                                                     للبيع فيلا مودرن فاخره درج بالصالة دبلكس\nحى الملقا\nالمساحه 200 م\nالشارع 20 م غربي\nالسعر مليون و 300الف سوم\nمدخل سيارة و غرفه سائق ومجلس و مقلط وصاله ومطبخ\nالدور الاول 4 غرف نوم و صاله و٣\nالدور العلوى غرفتين وصاله و السطح
# 2198  دور مؤسس 3 شقق\nدور حي طويق 2 \nمساحه 500\nدرج صاله شقتين\nشارع  20\n\nشغل جدا ممتاز\nمن ناحية التصميم \nوالشغل\n\nعليها جميع \nانواع الضمانات\nسباكه \nكهرباء\nعوازل \nخزانات\nمكتب ابراج نمار\nتقدم لكم احسن\n\nالحلول التمويليه\n\nلامتلاك بيت العمر\n\nبالتقسيط المريح \n\nونقد...
# 384                            فيلا درج في الصالة وشقتين ...فى حى طويق  ....تشطيب فاخر  ... زاويه علي شارعين ١٥م..... واجهه حجر اردني  .... جنوبيه ....غربيه ... عليها جميع الضمانات...سباكه... كهرباء... عوازل حراريه....خزانات...ابواب اتوماتيكيه....كما يوجد لدينا حلول تمويلية الميسر...
#
#       living_rooms
# 1538             0
# 8901             2
# 6098             2
# 9233             0
# 9425             1
# 9245             3
# 8803             0
# 4923             4
# 5842             5
# 8356             0
# 3052             5
# 6083             3
# 6221             2
# 962              0
# 8614             1
# 2103             5
# 8873             0
# 1929             5
# 9597             1
# 6789             0
# 3486             3
# 5931             5
# 9642             6
# 1293             1
# 3839             6
# 8038             5
# 9676             0
# 9828             4
# 2968             1
# 672              1
# 5124             0
# 8207             3
# 4513             4
# 4935             3
# 282              1
# 9573             0
# 6160             5
# 9063             0
# 9373             3
# 8139             1
# 9190             1
# 1048             2
# 7765             3
# 6735             5
# 205              0
# 9772             2
# 3088             0
# 8894             5
# 2198             1
# 384              1

# %%
# titles = houses['listTitle']
#locations = houses['location']
#locations_mask = locations.str.contains("الرياض", case=False)
#titles_mask = titles.str.contains("فيلا", case=False)
#print(len(titles[titles_mask]))
#print(len(locations[locations_mask]))

# %% [markdown]
# - listTitle: (فيلا) in each row
# - location: (الرياض) in each row

# %% [markdown]
# ---
# ## Merge Extra Features:

# %%
extra_features = pd.DataFrame()
extra_features['time_duration'] = time['time_duration']
extra_features['neighborhood'] = location_df['neighborhood']

extra_features
# Out:
#         time_duration neighborhood
# 0     7 days 00:00:00         نمار
# 1     0 days 00:01:00     الياسمين
# 2     1 days 00:00:00       الربيع
# 3    91 days 06:00:00         طويق
# 4     0 days 13:00:00       الرمال
# ...               ...          ...
# 9969  0 days 22:00:00          لبن
# 9970  0 days 08:00:00     الياسمين
# 9971 30 days 10:00:00       العارض
# 9972  0 days 01:00:00       الروضة
# 9973  0 days 09:00:00     الياسمين
#
# [9974 rows x 2 columns]

# %% [markdown]
# ---
# ## Save The Extra Features Into New CSV File

# %%
# save the extra features into csv file named "riyadh_houses_extra_features" for analysis use
extra_features.to_csv("../Data/riyadh_houses_extra_features.csv", index=False)
